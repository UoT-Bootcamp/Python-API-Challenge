# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
baseUrl = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

weatherCheck = []

recordCounter = 1
setCounter = 1

print("Beginning Data Retrieval")
print("------------------------------")

for city in cities:
    query_url = f"{baseUrl}q={city}&appid={weather_api_key}&units={units}"
    weatherResponse = requests.get(query_url).json()
    try:
        cityName = weatherResponse["name"]
        lat = weatherResponse["coord"]["lat"]
        lng = weatherResponse["coord"]["lon"]
        maxTemp = weatherResponse["main"]["temp_max"]    
        humidity = weatherResponse["main"]["humidity"]     
        cloudiness = weatherResponse["clouds"]["all"] 
        windSpeed = weatherResponse["wind"]["speed"] 
        country = weatherResponse["sys"]["country"]     
        date = weatherResponse["dt"]        
        
        weatherCheck.append({"City" : cityName,
                            "Lat": lat,
                            "Lng" : lng,
                            "Max Temp" : maxTemp,
                            "Humidity" : humidity,
                            "Cloudiness" : cloudiness,
                            "Wind Speed" : windSpeed,
                            "Country" : country,
                             "Date" : date
                            })
        
        if recordCounter > 50:
            setCounter += 1
            recordCounter = 1
        print(f"Processing Record {recordCounter} of Set {setCounter} | {city}")
        recordCounter += 1
        
    except:
        print("City not found. Skipping...")
        
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | belyy yar
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | asau
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | magistralnyy
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | kirakira
# Processing Record 13 of Set 1 | meulaboh
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | tuatapere
# City not found. Skipping...
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | sinnamary
# Processing Record 18 of Set 1 | krasnoselkup
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | houma
# Processing Record 21 of Set 1 | pitsunda
# City not found. Skipping...
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | husavik
# Processing Record 31 of Set 1 | dudinka
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | yulara
# Processing Record 36 of Set 1 | la ronge
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | acajutla
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 45 of Set 1 | ewo
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | tessalit
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | gat
# Processing Record 1 of Set 2 | curup
# Processing Record 2 of Set 2 | hofn
# City not found. Skipping...
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | kaeo
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | cayenne
# Processing Record 9 of Set 2 | havre-saint-pierre
# Processing Record 10 of Set 2 | batsfjord
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | geraldton
# City not found. Skipping...
# Processing Record 13 of Set 2 | buraydah
# Processing Record 14 of Set 2 | lodja
# Processing Record 15 of Set 2 | araguaina
# Processing Record 16 of Set 2 | ippy
# Processing Record 17 of Set 2 | del rio
# Processing Record 18 of Set 2 | ondjiva
# Processing Record 19 of Set 2 | kudahuvadhoo
# Processing Record 20 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | muskogee
# Processing Record 23 of Set 2 | verkhovazhye
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | hasaki
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | kieta
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | monrovia
# Processing Record 30 of Set 2 | bonavista
# Processing Record 31 of Set 2 | davila
# Processing Record 32 of Set 2 | lata
# Processing Record 33 of Set 2 | christchurch
# Processing Record 34 of Set 2 | tasiilaq
# City not found. Skipping...
# Processing Record 35 of Set 2 | san pedro de macoris
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | alenquer
# Processing Record 38 of Set 2 | thompson
# Processing Record 39 of Set 2 | puerto maldonado
# Processing Record 40 of Set 2 | waipawa
# Processing Record 41 of Set 2 | pacific grove
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | hovd
# Processing Record 44 of Set 2 | khasan
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | birao
# Processing Record 48 of Set 2 | broome
# Processing Record 49 of Set 2 | lincoln
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 2 | sungairaya
# Processing Record 1 of Set 3 | marzuq
# City not found. Skipping...
# Processing Record 2 of Set 3 | ostersund
# Processing Record 3 of Set 3 | kupang
# Processing Record 4 of Set 3 | poso
# Processing Record 5 of Set 3 | mamu kanjan
# Processing Record 6 of Set 3 | xining
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | ketchikan
# Processing Record 9 of Set 3 | odienne
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | kapaa
# Processing Record 12 of Set 3 | tepelene
# Processing Record 13 of Set 3 | sorland
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | middle island
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | anadyr
# Processing Record 18 of Set 3 | qasigiannguit
# Processing Record 19 of Set 3 | ankang
# Processing Record 20 of Set 3 | lasa
# Processing Record 21 of Set 3 | sharjah
# Processing Record 22 of Set 3 | sakaiminato
# Processing Record 23 of Set 3 | rio grande
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | akureyri
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | champerico
# Processing Record 28 of Set 3 | alofi
# City not found. Skipping...
# Processing Record 29 of Set 3 | kindu
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | lysva
# Processing Record 32 of Set 3 | tezu
# Processing Record 33 of Set 3 | porto novo
# Processing Record 34 of Set 3 | ahipara
# Processing Record 35 of Set 3 | olinda
# Processing Record 36 of Set 3 | chuy
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | chicama
# Processing Record 40 of Set 3 | kabo
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | champa
# Processing Record 43 of Set 3 | kruisfontein
# City not found. Skipping...
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | thinadhoo
# Processing Record 46 of Set 3 | hit
# Processing Record 47 of Set 3 | de aar
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | virden
# Processing Record 50 of Set 3 | rhede
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | daru
# Processing Record 3 of Set 4 | beringovskiy
# Processing Record 4 of Set 4 | beira
# City not found. Skipping...
# Processing Record 5 of Set 4 | cabo san lucas
# Processing Record 6 of Set 4 | horsham
# City not found. Skipping...
# Processing Record 7 of Set 4 | vallenar
# Processing Record 8 of Set 4 | jega
# Processing Record 9 of Set 4 | kezmarok
# Processing Record 10 of Set 4 | auki
# City not found. Skipping...
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | agropoli
# Processing Record 13 of Set 4 | sambava
# Processing Record 14 of Set 4 | bull savanna
# Processing Record 15 of Set 4 | yaval
# Processing Record 16 of Set 4 | uglegorsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 4 | ramnagar
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | grand gaube
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | los llanos de aridane
# Processing Record 22 of Set 4 | zhigansk
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | pasni
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | kitui
# Processing Record 27 of Set 4 | dawei
# Processing Record 28 of Set 4 | maceio
# Processing Record 29 of Set 4 | canmore
# Processing Record 30 of Set 4 | paita
# Processing Record 31 of Set 4 | chase
# Processing Record 32 of Set 4 | panguna
# Processing Record 33 of Set 4 | hobart
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | vrani
# Processing Record 36 of Set 4 | wau
# Processing Record 37 of Set 4 | lagoa
# Processing Record 38 of Set 4 | antofagasta
# Processing Record 39 of Set 4 | agadez
# Processing Record 40 of Set 4 | rio gallegos
# Processing Record 41 of Set 4 | east london
# City not found. Skipping...
# Processing Record 42 of Set 4 | pizarro
# Processing Record 43 of Set 4 | cidreira
# Processing Record 44 of Set 4 | chipinge
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | garden city
# Processing Record 48 of Set 4 | amuntai
# Processing Record 49 of Set 4 | port shepstone
# Processing Record 50 of Set 4 | qaqortoq
# Processing Record 1 of Set 5 | havelock
# Processing Record 2 of Set 5 | andenes
# Processing Record 3 of Set 5 | ipixuna
# Processing Record 4 of Set 5 | torbay
# City not found. Skipping...
# Processing Record 5 of Set 5 | bubaque
# Processing Record 6 of Set 5 | ulaangom
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | araouane
# Processing Record 9 of Set 5 | iqaluit
# City not found. Skipping...
# Processing Record 10 of Set 5 | itoman
# Processing Record 11 of Set 5 | pozhva
# Processing Record 12 of Set 5 | sola
# Processing Record 13 of Set 5 | college
# Processing Record 14 of Set 5 | asosa
# Processing Record 15 of Set 5 | phenix city
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | texarkana
# Processing Record 18 of Set 5 | nesna
# Processing Record 19 of Set 5 | goderich
# City not found. Skipping...
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | morgan city
# Processing Record 22 of Set 5 | baruun-urt
# Processing Record 23 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 24 of Set 5 | san andres
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | port-gentil
# Processing Record 27 of Set 5 | sivas
# Processing Record 28 of Set 5 | khalkhal
# Processing Record 29 of Set 5 | sao filipe
# Processing Record 30 of Set 5 | mnogovershinnyy
# Processing Record 31 of Set 5 | eureka
# Processing Record 32 of Set 5 | alihe
# City not found. Skipping...
# Processing Record 33 of Set 5 | kalmunai
# Processing Record 34 of Set 5 | cuamba
# Processing Record 35 of Set 5 | santa cruz del sur
# Processing Record 36 of Set 5 | hailar
# Processing Record 37 of Set 5 | kurumkan
# Processing Record 38 of Set 5 | jinchang
# Processing Record 39 of Set 5 | nelson bay
# Processing Record 40 of Set 5 | road town
# Processing Record 41 of Set 5 | abalak
# Processing Record 42 of Set 5 | jibuti
# Processing Record 43 of Set 5 | xingcheng
# Processing Record 44 of Set 5 | oktyabrskoye
# Processing Record 45 of Set 5 | puerto madryn
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | punakha
# Processing Record 48 of Set 5 | aksay
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | ozark
# Processing Record 1 of Set 6 | qandala
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | nalut
# Processing Record 4 of Set 6 | jucuaran
# Processing Record 5 of Set 6 | roald
# Processing Record 6 of Set 6 | zakamensk
# Processing Record 7 of Set 6 | konde
# Processing Record 8 of Set 6 | oranjemund
# Processing Record 9 of Set 6 | palana
# Processing Record 10 of Set 6 | huaicheng
# Processing Record 11 of Set 6 | caramay
# Processing Record 12 of Set 6 | baghdad
# Processing Record 13 of Set 6 | piet retief
# Processing Record 14 of Set 6 | san jose
# Processing Record 15 of Set 6 | dera bugti
# Processing Record 16 of Set 6 | alta floresta
# Processing Record 17 of Set 6 | lashio
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | matara
# Processing Record 20 of Set 6 | arlit
# Processing Record 21 of Set 6 | kyabe
# Processing Record 22 of Set 6 | dalvik
# Processing Record 23 of Set 6 | lichtenburg
# Processing Record 24 of Set 6 | genhe
# Processing Record 25 of Set 6 | morro bay
# Processing Record 26 of Set 6 | baoshan
# Processing Record 27 of Set 6 | lannion
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 6 | znamenskoye
# Processing Record 29 of Set 6 | quelimane
# Processing Record 30 of Set 6 | chitipa
# Processing Record 31 of Set 6 | chokurdakh
# Processing Record 32 of Set 6 | pochutla
# Processing Record 33 of Set 6 | comodoro rivadavia
# Processing Record 34 of Set 6 | sangar
# Processing Record 35 of Set 6 | taoudenni
# Processing Record 36 of Set 6 | klaksvik
# Processing Record 37 of Set 6 | sparks
# Processing Record 38 of Set 6 | sao jose de ribamar
# Processing Record 39 of Set 6 | tshikapa
# Processing Record 40 of Set 6 | raudeberg
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | port blair
# Processing Record 43 of Set 6 | chkalovskoye
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | axim
# Processing Record 46 of Set 6 | mao
# Processing Record 47 of Set 6 | lompoc
# Processing Record 48 of Set 6 | lubango
# Processing Record 49 of Set 6 | maragogi
# Processing Record 50 of Set 6 | pokhara
# Processing Record 1 of Set 7 | angoche
# Processing Record 2 of Set 7 | oum hadjer
# Processing Record 3 of Set 7 | saint-francois
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | carroll
# Processing Record 6 of Set 7 | turukhansk
# Processing Record 7 of Set 7 | camapua
# Processing Record 8 of Set 7 | antalaha
# Processing Record 9 of Set 7 | kholmogory
# Processing Record 10 of Set 7 | kinango
# Processing Record 11 of Set 7 | anshun
# Processing Record 12 of Set 7 | zhangjiakou
# Processing Record 13 of Set 7 | akyab
# Processing Record 14 of Set 7 | norman wells
# Processing Record 15 of Set 7 | beloha
# Processing Record 16 of Set 7 | muroto
# Processing Record 17 of Set 7 | saint-joseph
# Processing Record 18 of Set 7 | weligama
# Processing Record 19 of Set 7 | hommelvik
# Processing Record 20 of Set 7 | soyo
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | evensk
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | coihaique
# City not found. Skipping...
# Processing Record 25 of Set 7 | taywarah
# Processing Record 26 of Set 7 | hualmay
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | wamba
# Processing Record 29 of Set 7 | luanda
# Processing Record 30 of Set 7 | suraabad
# City not found. Skipping...
# Processing Record 31 of Set 7 | bay roberts
# Processing Record 32 of Set 7 | pevek
# Processing Record 33 of Set 7 | ferkessedougou
# Processing Record 34 of Set 7 | goundam
# Processing Record 35 of Set 7 | sayat
# Processing Record 36 of Set 7 | dingle
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | kukmor
# City not found. Skipping...
# Processing Record 39 of Set 7 | marienburg
# Processing Record 40 of Set 7 | bilma
# Processing Record 41 of Set 7 | port moresby
# Processing Record 42 of Set 7 | devarkonda
# Processing Record 43 of Set 7 | kununurra
# Processing Record 44 of Set 7 | faanui
# Processing Record 45 of Set 7 | shingu
# Processing Record 46 of Set 7 | churapcha
# Processing Record 47 of Set 7 | cloquet
# Processing Record 48 of Set 7 | hatod
# Processing Record 49 of Set 7 | sao paulo de olivenca
# Processing Record 50 of Set 7 | male
# City not found. Skipping...
# Processing Record 1 of Set 8 | acapulco
# Processing Record 2 of Set 8 | santa fe
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | ibb
# Processing Record 5 of Set 8 | hervey bay
# Processing Record 6 of Set 8 | sun city west
# Processing Record 7 of Set 8 | pudozh
# Processing Record 8 of Set 8 | rincon
# Processing Record 9 of Set 8 | tupik
# Processing Record 10 of Set 8 | waddan
# Processing Record 11 of Set 8 | umm lajj
# Processing Record 12 of Set 8 | nuuk
# Processing Record 13 of Set 8 | papara
# Processing Record 14 of Set 8 | stulovo
# Processing Record 15 of Set 8 | huaraz
# Processing Record 16 of Set 8 | presidencia roque saenz pena
# Processing Record 17 of Set 8 | palo alto
# Processing Record 18 of Set 8 | langsa
# Processing Record 19 of Set 8 | mahibadhoo
# Processing Record 20 of Set 8 | kilis
# Processing Record 21 of Set 8 | saurimo
# Processing Record 22 of Set 8 | olafsvik
# City not found. Skipping...
# Processing Record 23 of Set 8 | teluknaga
# Processing Record 24 of Set 8 | kamenka
# Processing Record 25 of Set 8 | springbok
# Processing Record 26 of Set 8 | sydney
# Processing Record 27 of Set 8 | kautokeino
# Processing Record 28 of Set 8 | eyl
# Processing Record 29 of Set 8 | provo
# Processing Record 30 of Set 8 | san juan
# Processing Record 31 of Set 8 | belaya gora
# Processing Record 32 of Set 8 | honiara
# Processing Record 33 of Set 8 | shipunovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 8 | marystown
# Processing Record 35 of Set 8 | iberia
# City not found. Skipping...
# Processing Record 36 of Set 8 | vizinga
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | vostok
# Processing Record 39 of Set 8 | vanavara
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | laguna
# Processing Record 42 of Set 8 | savannah bight
# Processing Record 43 of Set 8 | blythe
# Processing Record 44 of Set 8 | touros
# Processing Record 45 of Set 8 | vao
# City not found. Skipping...
# Processing Record 46 of Set 8 | peruibe
# Processing Record 47 of Set 8 | bon accord
# Processing Record 48 of Set 8 | rudnogorsk
# Processing Record 49 of Set 8 | bara
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | shaowu
# Processing Record 2 of Set 9 | harper
# Processing Record 3 of Set 9 | popondetta
# Processing Record 4 of Set 9 | dakar
# Processing Record 5 of Set 9 | mitsamiouli
# Processing Record 6 of Set 9 | rawah
# City not found. Skipping...
# Processing Record 7 of Set 9 | srednekolymsk
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | mount gambier
# Processing Record 10 of Set 9 | chernushka
# Processing Record 11 of Set 9 | taksimo
# Processing Record 12 of Set 9 | kyren
# City not found. Skipping...
# Processing Record 13 of Set 9 | basco
# Processing Record 14 of Set 9 | concepcion del oro
# Processing Record 15 of Set 9 | romny
# City not found. Skipping...
# Processing Record 16 of Set 9 | vakhrushev
# Processing Record 17 of Set 9 | windsor
# Processing Record 18 of Set 9 | pemangkat
# Processing Record 19 of Set 9 | natal
# Processing Record 20 of Set 9 | arman
# Processing Record 21 of Set 9 | murray bridge
# Processing Record 22 of Set 9 | carballo
# Processing Record 23 of Set 9 | progreso
# Processing Record 24 of Set 9 | mahon
# Processing Record 25 of Set 9 | bandarbeyla
# Processing Record 26 of Set 9 | apricena
# Processing Record 27 of Set 9 | mahajanga
# Processing Record 28 of Set 9 | qui nhon
# Processing Record 29 of Set 9 | joao pinheiro
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | lethem
# Processing Record 32 of Set 9 | chenzhou
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | moron
# Processing Record 35 of Set 9 | huai thalaeng
# Processing Record 36 of Set 9 | maniwaki
# Processing Record 37 of Set 9 | baykit
# Processing Record 38 of Set 9 | isla aguada
# Processing Record 39 of Set 9 | goure
# Processing Record 40 of Set 9 | ibi
# Processing Record 41 of Set 9 | morros
# Processing Record 42 of Set 9 | ulaanbaatar
# Processing Record 43 of Set 9 | radom
# City not found. Skipping...
# Processing Record 44 of Set 9 | namatanai
# City not found. Skipping...
# Processing Record 45 of Set 9 | malinovskiy
# Processing Record 46 of Set 9 | ornskoldsvik
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | guano
# Processing Record 49 of Set 9 | grandview
# City not found. Skipping...
# Processing Record 50 of Set 9 | kalemie
# Processing Record 1 of Set 10 | nagato
# Processing Record 2 of Set 10 | buchanan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 10 | cancun
# City not found. Skipping...
# Processing Record 4 of Set 10 | kargil
# Processing Record 5 of Set 10 | terney
# Processing Record 6 of Set 10 | kochevo
# Processing Record 7 of Set 10 | nizhniy kuranakh
# Processing Record 8 of Set 10 | san carlos de bariloche
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | sunbury
# Processing Record 11 of Set 10 | jardim
# Processing Record 12 of Set 10 | horqueta
# Processing Record 13 of Set 10 | cabedelo
# Processing Record 14 of Set 10 | urubicha
# Processing Record 15 of Set 10 | corner brook
# Processing Record 16 of Set 10 | bonthe
# City not found. Skipping...
# Processing Record 17 of Set 10 | aranos
# Processing Record 18 of Set 10 | ust-kan
# City not found. Skipping...
# Processing Record 19 of Set 10 | guarapari
# Processing Record 20 of Set 10 | dali
# Processing Record 21 of Set 10 | tibati
# Processing Record 22 of Set 10 | raiwala
# Processing Record 23 of Set 10 | sept-iles
# Processing Record 24 of Set 10 | hambantota
# Processing Record 25 of Set 10 | uyuni
# Processing Record 26 of Set 10 | tomatlan
# Processing Record 27 of Set 10 | egvekinot
# Processing Record 28 of Set 10 | portland
# Processing Record 29 of Set 10 | saint-louis
# Processing Record 30 of Set 10 | solnechnyy
# Processing Record 31 of Set 10 | talnakh
# Processing Record 32 of Set 10 | tromso
# Processing Record 33 of Set 10 | chino valley
# Processing Record 34 of Set 10 | aklavik
# Processing Record 35 of Set 10 | huamuxtitlan
# Processing Record 36 of Set 10 | yerbogachen
# Processing Record 37 of Set 10 | skibbereen
# Processing Record 38 of Set 10 | bata
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | roebourne
# Processing Record 41 of Set 10 | grahamstown
# Processing Record 42 of Set 10 | okhotsk
# Processing Record 43 of Set 10 | saint-leu
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | pinega
# Processing Record 46 of Set 10 | najran
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | bafra
# Processing Record 49 of Set 10 | molo
# Processing Record 50 of Set 10 | vila velha
# Processing Record 1 of Set 11 | half moon bay
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | vila franca do campo
# Processing Record 4 of Set 11 | novochernorechenskiy
# Processing Record 5 of Set 11 | victoria point
# Processing Record 6 of Set 11 | umm kaddadah
# Processing Record 7 of Set 11 | mezen
# Processing Record 8 of Set 11 | kattivakkam
# Processing Record 9 of Set 11 | sarakhs
# City not found. Skipping...
# Processing Record 10 of Set 11 | siguiri
# Processing Record 11 of Set 11 | buala
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | numazu
# Processing Record 14 of Set 11 | karasuk
# Processing Record 15 of Set 11 | strai
# City not found. Skipping...
# Processing Record 16 of Set 11 | revelstoke
# Processing Record 17 of Set 11 | costeiu
# Processing Record 18 of Set 11 | luganville
# Processing Record 19 of Set 11 | severo-kurilsk
# Processing Record 20 of Set 11 | nacozari
# Processing Record 21 of Set 11 | da lat
# Processing Record 22 of Set 11 | dilla
# City not found. Skipping...
# Processing Record 23 of Set 11 | qianan
# Processing Record 24 of Set 11 | mitu
# Processing Record 25 of Set 11 | wanaka
# Processing Record 26 of Set 11 | seoul
# Processing Record 27 of Set 11 | aguimes
# Processing Record 28 of Set 11 | porto walter
# Processing Record 29 of Set 11 | casma
# Processing Record 30 of Set 11 | stornoway
# Processing Record 31 of Set 11 | nagaur
# Processing Record 32 of Set 11 | la asuncion
# Processing Record 33 of Set 11 | itarema
# Processing Record 34 of Set 11 | teahupoo
# Processing Record 35 of Set 11 | omboue
# Processing Record 36 of Set 11 | cherskiy
# Processing Record 37 of Set 11 | xichang
# Processing Record 38 of Set 11 | port lincoln
# Processing Record 39 of Set 11 | dunedin
# Processing Record 40 of Set 11 | fortuna
# Processing Record 41 of Set 11 | alugan
# Processing Record 42 of Set 11 | abonnema
# Processing Record 43 of Set 11 | itapolis
# Processing Record 44 of Set 11 | la sarre
# City not found. Skipping...
# Processing Record 45 of Set 11 | mehran
# Processing Record 46 of Set 11 | waverly
# Processing Record 47 of Set 11 | paamiut
# Processing Record 48 of Set 11 | sechura
# Processing Record 49 of Set 11 | kushiro
# Processing Record 50 of Set 11 | elektrogorsk
# Processing Record 1 of Set 12 | thongwa
# Processing Record 2 of Set 12 | teguldet
# Processing Record 3 of Set 12 | hobyo
# Processing Record 4 of Set 12 | bilibino
# Processing Record 5 of Set 12 | fukue
# Processing Record 6 of Set 12 | humble
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | wattegama
# Processing Record 9 of Set 12 | olonets
# Processing Record 10 of Set 12 | elko
# Processing Record 11 of Set 12 | guangyuan
# Processing Record 12 of Set 12 | burayevo
# Processing Record 13 of Set 12 | ewa beach
# Processing Record 14 of Set 12 | paragominas
# Processing Record 15 of Set 12 | huarmey
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# #######

# %%
cityData_df = pd.DataFrame(weatherCheck)
cityData_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    George Town   5.41  100.34     77.00        88          20        4.52
# 1      Belyy Yar  53.60   91.39     53.60        93          41        4.47
# 2        Rikitea -23.12 -134.97     69.46        70          13       15.95
# 3           Asău  46.43   26.40     57.99        91           0        4.14
# 4    Port Alfred -33.59   26.89     52.00        72          37        5.01
# ..           ...    ...     ...       ...       ...         ...         ...
# 560    Guangyuan  32.44  105.82     63.00        89         100        5.53
# 561     Burayevo  55.84   55.41     58.98        87           0        4.68
# 562   ‘Ewa Beach  21.32 -158.01     87.80        52          75        5.82
# 563  Paragominas  -2.97  -47.48     72.45        97          58        3.29
# 564      Huarmey -10.07  -78.15     63.07        76           1        9.04
#
#     Country        Date
# 0        MY  1594508664
# 1        RU  1594508784
# 2        PF  1594508784
# 3        RO  1594508784
# 4        ZA  1594508504
# ..      ...         ...
# 560      CN  1594508522
# 561      RU  1594508813
# 562      US  1594508604
# 563      BR  1594508813
# 564      PE  1594508813
#
# [565 rows x 9 columns]

# %%
#######

cityData_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cityData_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    20.261221   18.266867   68.747062   71.237168   50.054867    8.035186
# std     33.312941   89.247995   15.024120   20.146459   37.466943    5.627409
# min    -54.800000 -179.170000   32.000000    3.000000    0.000000    0.430000
# 25%     -6.320000  -58.650000   56.620000   60.000000   14.000000    3.890000
# 50%     22.890000   20.800000   71.080000   76.000000   49.000000    6.930000
# 75%     48.970000   96.130000   79.430000   86.000000   90.000000   10.290000
# max     78.220000  179.320000  116.010000  100.000000  100.000000   35.160000
#
#                Date
# count  5.650000e+02
# mean   1.594509e+09
# std    8.316894e+01
# min    1.594509e+09
# 25%    1.594509e+09
# 50%    1.594509e+09
# 75%    1.594509e+09
# max    1.594509e+09

# %%
#  Get the indices of cities that have humidity over 100%.
over100Humidity = cityData_df.loc[cityData_df["Humidity"] > 100]
over100Humidity_index = over100Humidity.index
over100Humidity_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
cleanCityData_df = cityData_df.drop(labels = over100Humidity_index, inplace = False)


cleanCityData_df
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    George Town   5.41  100.34     77.00        88          20        4.52
# 1      Belyy Yar  53.60   91.39     53.60        93          41        4.47
# 2        Rikitea -23.12 -134.97     69.46        70          13       15.95
# 3           Asău  46.43   26.40     57.99        91           0        4.14
# 4    Port Alfred -33.59   26.89     52.00        72          37        5.01
# ..           ...    ...     ...       ...       ...         ...         ...
# 560    Guangyuan  32.44  105.82     63.00        89         100        5.53
# 561     Burayevo  55.84   55.41     58.98        87           0        4.68
# 562   ‘Ewa Beach  21.32 -158.01     87.80        52          75        5.82
# 563  Paragominas  -2.97  -47.48     72.45        97          58        3.29
# 564      Huarmey -10.07  -78.15     63.07        76           1        9.04
#
#     Country        Date
# 0        MY  1594508664
# 1        RU  1594508784
# 2        PF  1594508784
# 3        RO  1594508784
# 4        ZA  1594508504
# ..      ...         ...
# 560      CN  1594508522
# 561      RU  1594508813
# 562      US  1594508604
# 563      BR  1594508813
# 564      PE  1594508813
#
# [565 rows x 9 columns]

# %%
# # Extract relevant fields from the data frame
latitude = cleanCityData_df["Lat"]
longitude = cleanCityData_df["Lng"]
temperature = cleanCityData_df["Max Temp"]
humidity = cleanCityData_df["Humidity"]
cloudiness = cleanCityData_df["Cloudiness"]
wind_speed = cleanCityData_df["Wind Speed"]

cleanCityData_df.reset_index()
cleanCityData_df.index.name = "City_ID"

# Export the City_Data into a csv

outputData = cleanCityData_df.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# plt.hlines(temperature, xmin = min(latitude), xmax = max(latitude))

currentDate = pd.to_datetime("today")
currentDate = currentDate.strftime("%d/%m/%y")

plt.scatter(latitude, temperature, marker = "o", alpha = 0.75, edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({currentDate})")
##### plt.ylim(0, max(temperature))
plt.grid(True)
plt.savefig("../Output/lat_temp.png")

# %% [markdown]
# # Observable Trends:
#
# * As we approach the equator, the weather gets hotter.
# * As we move away from the equator i.e. towards northern hemisphere or southern hemisphere, the temperature decreases.
# * At the latitude between 20 to 40 degrees, we observe maximum temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# plt.figure(figsize = (8,8))
plt.scatter(latitude, humidity, marker = "o", alpha = 0.75, edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({currentDate})")
# ##### plt.ylim(0, max(temperature))
plt.grid(True)
plt.savefig("../Output/lat_humidity.png")

# %% [markdown]
# # Observable Trend:
#
# * The Northern hemisphere has more humid weather than Southern hemisphere.
# * Most city has higher humidity percentage i.e. greater than 60%.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude, cloudiness, marker = "o", alpha = 0.75, edgecolors = "black" )
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness ({currentDate})")
# ##### plt.ylim(0, max(temperature))
plt.grid(True)
plt.savefig("../Output/lat_cloudiness.png")

# %% [markdown]
# # Observable Trend:
#
# There is no observable trend between latitude and cloudiness. In other words, we can say that cloudiness does not depend on latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude, wind_speed, marker = "o", alpha = 0.75, edgecolors = "black" )
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({currentDate})")
# ##### plt.ylim(0, max(temperature))
plt.grid(True)
plt.savefig("../Output/lat_windSpeed.png")

# %% [markdown]
# # Observable Trend:
#
# * The range of wind speed lies between 0 mph to 10 mph.
# * Cities near the extreme southern or northern hemisphere observe increase in wind speed.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linearRegression(x_value, y_value, x_annotation, y_annotation):
 
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    print(f"The r-squared is: {rvalue** 2}")
    regress_values = x_value * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_value,y_value, marker="o", edgecolors = "black", alpha = 0.75)
    plt.plot(x_value,regress_values,"r-")
    plt.annotate(line_eq,(x_annotation, y_annotation),fontsize = 20, color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
northernHemisphere = []
southernHemisphere = []

for city in cities:
    query_url = f"{baseUrl}q={city}&appid={weather_api_key}&units={units}"
    response = requests.get(query_url).json()
    print
    try:

        if response["coord"]["lat"] >= 0:

            cityName = response["name"]
            lat = response["coord"]["lat"]
            lng = response["coord"]["lon"]
            maxTemp = response["main"]["temp_max"]    
            humidity = response["main"]["humidity"]     
            cloudiness = response["clouds"]["all"] 
            windSpeed = response["wind"]["speed"] 
            country = response["sys"]["country"]     
            date = response["dt"]        
        
            northernHemisphere.append({"City" : cityName,
                            "Lat": lat,
                            "Lng" : lng,
                            "Max Temp" : maxTemp,
                            "Humidity" : humidity,
                            "Cloudiness" : cloudiness,
                            "Wind Speed" : windSpeed,
                            "Country" : country,
                             "Date" : date
                            })
        else:
            
            cityName = response["name"]
            lat = response["coord"]["lat"]
            lng = response["coord"]["lon"]
            maxTemp = response["main"]["temp_max"]    
            humidity = response["main"]["humidity"]     
            cloudiness = response["clouds"]["all"] 
            windSpeed = response["wind"]["speed"] 
            country = response["sys"]["country"]     
            date = response["dt"]        
        
            southernHemisphere.append({"City" : cityName,
                            "Lat": lat,
                            "Lng" : lng,
                            "Max Temp" : maxTemp,
                            "Humidity" : humidity,
                            "Cloudiness" : cloudiness,
                            "Wind Speed" : windSpeed,
                            "Country" : country,
                             "Date" : date
                            })
           
    except:
        
        print("City not found. Skipping...")
# Out:
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...

# %%
northernHemisphere_df = pd.DataFrame(northernHemisphere)
southernHemisphere_df = pd.DataFrame(southernHemisphere)

northernHemisphere_data = northernHemisphere_df.to_csv("../Output/northern_hemisphere_data.csv")

northernHemisphere_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    George Town   5.41  100.34     77.00        88          20        4.52
# 1      Belyy Yar  53.60   91.39     53.60        93          41        4.47
# 2           Asău  46.43   26.40     57.99        91           0        4.14
# 3  Magistral'nyy  56.17  107.45     62.92        85          96        3.83
# 4       Meulaboh   4.14   96.13     75.34        87         100        3.22
#
#   Country        Date
# 0      MY  1594508664
# 1      RU  1594508784
# 2      RO  1594508784
# 3      RU  1594508785
# 4      ID  1594508874

# %%
southernHemisphere_data = southernHemisphere_df.to_csv("../Output/southern_hemisphere_data.csv")

southernHemisphere_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Rikitea -23.12 -134.97     69.46        70          13       15.95
# 1   Port Alfred -33.59   26.89     52.00        72          37        5.01
# 2       Mataura -46.19  168.86     46.04        92          72        5.82
# 3     Carnarvon -24.87  113.63     55.40        30           0       11.41
# 4  Punta Arenas -53.15  -70.92     33.80        74          40        9.17
#
#   Country        Date
# 0      PF  1594508784
# 1      ZA  1594508504
# 2      NZ  1594508785
# 3      AU  1594508785
# 4      CL  1594508527

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(northernHemisphere_df["Lat"], northernHemisphere_df["Max Temp"], northernHemisphere_df["Lat"].min(), northernHemisphere_df["Max Temp"].min())  
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.savefig("../Output/linreg_north_lat_temp.png")
plt.show()
# Out:
# The r-squared is: 0.44874112549516737

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(southernHemisphere_df["Lat"], southernHemisphere_df["Max Temp"], southernHemisphere_df["Lat"].min(), southernHemisphere_df["Max Temp"].min())
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.savefig("../Output/linreg_south_lat_temp.png")
plt.show()
# Out:
# The r-squared is: 0.6146523566758862

# %% [markdown]
# # Observable Trends - Northern and Southern hemisphere Latitude vs Max Temp
#
# * As we move away from the equator, we observe a decrease in temperature.
# * The r-squared value of northern hemisphere is 0.44 which means  that the model explains almost all the variability of the data around its mean.
# * As per the Southern hemisphere plot, we observe that as we approach towards the equator, the temperature increases.
# *  The r-squared value of southern hemisphere is 0.54 which means  that the model explains almost all the variability of the data around its mean.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(northernHemisphere_df["Lat"], northernHemisphere_df["Humidity"], northernHemisphere_df["Lat"].min() , northernHemisphere_df["Humidity"].min())
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Output/linreg_north_lat_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.0005316028821152512

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(southernHemisphere_df["Lat"], southernHemisphere_df["Humidity"], southernHemisphere_df["Lat"].min() , southernHemisphere_df["Humidity"].min() )
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Output/linreg_south_lat_humidity.png")
plt.show()
# Out:
# The r-squared is: 0.006415443316225701

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(northernHemisphere_df["Lat"], northernHemisphere_df["Cloudiness"], 10, 43)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Output/linreg_north_lat_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.010363368925041787

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(southernHemisphere_df["Lat"], southernHemisphere_df["Cloudiness"], -50, 50)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Output/linreg_south_lat_cloudiness.png")
plt.show()
# Out:
# The r-squared is: 0.009109367074206363

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(northernHemisphere_df["Lat"], northernHemisphere_df["Wind Speed"], 10, 30)
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Output/linreg_north_lat_wind.png")
plt.show()
# Out:
# The r-squared is: 0.0012291696402058595

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(southernHemisphere_df["Lat"], southernHemisphere_df["Wind Speed"], -50, 25)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Output/linreg_south_lat_wind.png")
plt.show()
# Out:
# The r-squared is: 0.057903459079709854
